# %%
import pandas as pd
data=pd.read_csv("/content/archive (1).zip")
description=data.describe()
print(description)
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data_types = data.dtypes
data_shape = data.shape
print("Data Types:\n", data_types)
print("Data Shape:", data_shape)
# Out:
# Data Types:
#  longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object
# Data Shape: (20640, 10)

# %%
nullvalues=data.isnull()
print(nullvalues)
t_mean=data.fillna(0)
print(t_mean)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
X = data.drop(columns=["median_house_value"])
y = data["median_house_value"]

print("Features (X):\n", X.head())
print("\nTarget (y):\n", y.head())
# Out:
# Features (X):
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income ocean_proximity
# 0       322.0       126.0         8.3252        NEAR BAY
# 1      2401.0      1138.0         8.3014        NEAR BAY
# 2       496.0       177.0         7.2574        NEAR BAY
# 3       558.0       219.0         5.6431        NEAR BAY
# 4       565.0       259.0         3.8462        NEAR BAY
#
# Target (y):
#  0    452600.0
# 1    358500.0
# 2    352100.0
# 3    341300.0
# 4    342200.0
# Name: median_house_value, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print("Train set shape:", X_train.shape)
print("Test set shape:", X_test.shape)
# Out:
# Train set shape: (16512, 9)
# Test set shape: (4128, 9)

# %%
from sklearn.preprocessing import MinMaxScaler
data['median_house_value'] = data['median_house_value'].replace('M', 1)
data['median_house_value'] = data['median_house_value'].replace('B', 0)
data['median_house_value'] = pd.to_numeric(data['population'], errors='coerce')
scaler = MinMaxScaler()
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns
data[numerical_columns] = scaler.fit_transform(data[numerical_columns])

print(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       0.211155  0.567481            0.784314     0.022331        0.020016
# 1       0.212151  0.565356            0.392157     0.180503        0.171606
# 2       0.210159  0.564293            1.000000     0.037260        0.029480
# 3       0.209163  0.564293            1.000000     0.032352        0.036462
# 4       0.209163  0.564293            1.000000     0.041330        0.043445
# ...          ...       ...                 ...          ...             ...
# 20635   0.324701  0.737513            0.470588     0.042296        0.058029
# 20636   0.312749  0.738576            0.333333     0.017676        0.023274
# 20637   0.311753  0.732200            0.313725     0.057277        0.075252
# 20638   0.301793  0.732200            0.333333     0.047256        0.063460
# 20639   0.309761  0.725824            0.294118     0.070782        0.095578
#
# ...

# %%
model = LinearRegression()
model.fit(X_train_scaled, y_train)

print("Model trained successfully.")

predictions = model.predict(X_test_scaled)

mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
rmse = np.sqrt(mse)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
# Out:
# Model trained successfully.
# Mean Squared Error: 13054453560.316599
# Mean Absolute Error: 90733.74386922989
# Root Mean Squared Error: 114256.0876291351

# %%
w_values = model.coef_
print("Coefficients (w values):", w_values)
# Out:
# Coefficients (w values): [ 22008.81320526  17211.56855604  -5453.07499679 -10400.29362631
#  -13452.12955455   -153.79538269  43965.42110065    215.51349744
#   -5477.33595415  -6532.79339039  15283.04196129  -1178.62308174
#   -2094.289535  ]
